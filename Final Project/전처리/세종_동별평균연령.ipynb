# %%
import pandas as pd
import numpy as np

# %%
d=pd.read_excel("C:/Users/user/Final Project/원데이터/세종시_동별연령대평균.xlsx")
d
# Out:
#       No                                               행정구역    평균    남자    여자
# 0    1.0                                        세종특별자치시 전동면  58.5  56.7  60.5
# 1    2.0                                        세종특별자치시 연동면  57.4  54.6  60.4
# 2    3.0                                        세종특별자치시 금남면  54.5  52.3  57.1
# 3    4.0                                        세종특별자치시 전의면  54.2  51.7  57.0
# 4    5.0                                        세종특별자치시 연서면  53.0  50.4  56.1
# 5    6.0                                        세종특별자치시 소정면  52.8  51.1  54.7
# 6    7.0                                        세종특별자치시 연기면  51.8  49.8  54.6
# 7    8.0                                        세종특별자치시 부강면  51.1  49.0  53.8
# 8    9.0                                        세종특별자치시 장군면  50.0  48.1  52.7
# 9   10.0                                       세종특별자치시 조치원읍  44.4  43.1  45.8
# 10  11.0                                            세종특별자치시  38.5  38.0  39.1
# ...

# %%
df=d.iloc[list(range(0, 10)) + list(range(12, 26)), 1:]
df
# Out:
#             행정구역    평균    남자    여자
# 0    세종특별자치시 전동면  58.5  56.7  60.5
# 1    세종특별자치시 연동면  57.4  54.6  60.4
# 2    세종특별자치시 금남면  54.5  52.3  57.1
# 3    세종특별자치시 전의면  54.2  51.7  57.0
# 4    세종특별자치시 연서면  53.0  50.4  56.1
# 5    세종특별자치시 소정면  52.8  51.1  54.7
# 6    세종특별자치시 연기면  51.8  49.8  54.6
# 7    세종특별자치시 부강면  51.1  49.0  53.8
# 8    세종특별자치시 장군면  50.0  48.1  52.7
# 9   세종특별자치시 조치원읍  44.4  43.1  45.8
# 12   세종특별자치시 도담동  37.8  37.1  38.5
# 13   세종특별자치시 대평동  37.5  36.7  38.3
# 14   세종특별자치시 한솔동  37.1  36.4  37.7
# 15   세종특별자치시 종촌동  36.8  36.2  37.3
# 16   세종특별자치시 보람동  36.1  35.8  36.4
# 17   세종특별자치시 소담동  35.7  35.4  36.1
# 18   세종특별자치시 아름동  35.5  34.9  36.0
# 19   세종특별자치시 고운동  35.4  34.8  36.0
# 20   세종특별자치시 새롬동  35.3  34.9  35.6
# 21   세종특별자치시 다정동  35.0  34.5  35.4
# 22   세종특별자치시 어진동  34.2  34.3  34.0
# 23   세종특별자치시 나성동  33.8  34.1  33.5
# 24   세종특별자치시 해밀동  33.6  33.2  33.9
# 25   세종특별자치시 반곡동  33.3  33.3  33.4

# %%
df['행정구역']=df['행정구역'].str.replace('세종특별자치시','').str.strip()

# %%
df
# Out:
#     행정구역    평균    남자    여자
# 0    전동면  58.5  56.7  60.5
# 1    연동면  57.4  54.6  60.4
# 2    금남면  54.5  52.3  57.1
# 3    전의면  54.2  51.7  57.0
# 4    연서면  53.0  50.4  56.1
# 5    소정면  52.8  51.1  54.7
# 6    연기면  51.8  49.8  54.6
# 7    부강면  51.1  49.0  53.8
# 8    장군면  50.0  48.1  52.7
# 9   조치원읍  44.4  43.1  45.8
# 12   도담동  37.8  37.1  38.5
# 13   대평동  37.5  36.7  38.3
# 14   한솔동  37.1  36.4  37.7
# 15   종촌동  36.8  36.2  37.3
# 16   보람동  36.1  35.8  36.4
# 17   소담동  35.7  35.4  36.1
# 18   아름동  35.5  34.9  36.0
# 19   고운동  35.4  34.8  36.0
# 20   새롬동  35.3  34.9  35.6
# 21   다정동  35.0  34.5  35.4
# 22   어진동  34.2  34.3  34.0
# 23   나성동  33.8  34.1  33.5
# 24   해밀동  33.6  33.2  33.9
# 25   반곡동  33.3  33.3  33.4

# %% [markdown]
# sejong=d.iloc[11,1:]
# sejong=pd.DataFrame(sejong).T
# sejong

# %% [markdown]
# df = pd.concat([df,sejong])
# df

# %%
df.to_csv("C:/Users/user/Final Project/csv/dong_age.csv")
