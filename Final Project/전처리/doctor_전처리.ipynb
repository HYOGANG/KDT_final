# %%
import pandas as pd

# %%
a=pd.read_excel("C:/Users/user/Final Project/원데이터/doctor.xlsx", header =None)

# %%
a
# Out:
#                                  0       1    2    3    4     5    6      7   \
# 0   지역별종별_의료인력현황_의사등(단위_명)_2023년3분기     NaN  NaN  NaN  NaN   NaN  NaN    NaN
# 1                               NaN     NaN  NaN  NaN  NaN   NaN  NaN    NaN
# 2                               NaN  인력코드상위   의사   의사   의사    의사   의사   치과의사
# 3                                시도  요양기관종별  의사계  일반의   인턴  레지던트  전문의  치과의사계
# 4                                세종      소계  531   32    0     -  499    144
# 5                                세종    종합병원  159    -    0     -  159      4
# 6                                세종      병원   16    -    -     -   16      -
# 7                                세종    요양병원    8    -    -     -    8      -
# 8                                세종    정신병원    2    -    -     -    2      -
# 9                                세종      의원  339   26    -     -  313      -
# 10                               세종    치과병원    -    -    -     -    -     11
# ...

# %%
ad=a.iloc[5:,[1,2,7,12,18]]
ad.columns=['type','의사','치과의사','한의사','약사']
ad=ad.replace(to_replace={'-':'0'})
ad
# Out:
#     type   의사 치과의사  한의사   약사
# 5   종합병원  159    4    0   17
# 6     병원   16    0    0    2
# 7   요양병원    8    0    4    3
# 8   정신병원    2    0    0    0
# 9     의원  339    0    0    0
# 10  치과병원    0   11    0    0
# 11  치과의원    0  124    0    0
# 12   보건소    2    2    2    0
# 13  보건지소    4    3    4    0
# 14    약국    0    0    0  231
# 15  한방병원    1    0   14    1
# 16   한의원    0    0  105    0

# %%
ad.dtypes
ad = ad.astype({'의사':'int','치과의사':'int','한의사':'int' ,'약사':'int'})

# %%
ad.dtypes
# Out:
# type    object
# 의사       int32
# 치과의사     int32
# 한의사      int32
# 약사       int32
# dtype: object

# %%
ad["총합"] = ad.iloc[:,1:].sum(axis=1)
ad
# Out:
#     type   의사  치과의사  한의사   약사   총합
# 5   종합병원  159     4    0   17  180
# 6     병원   16     0    0    2   18
# 7   요양병원    8     0    4    3   15
# 8   정신병원    2     0    0    0    2
# 9     의원  339     0    0    0  339
# 10  치과병원    0    11    0    0   11
# 11  치과의원    0   124    0    0  124
# 12   보건소    2     2    2    0    6
# 13  보건지소    4     3    4    0   11
# 14    약국    0     0    0  231  231
# 15  한방병원    1     0   14    1   16
# 16   한의원    0     0  105    0  105

# %%
df=a.iloc[4:,1:3]
df=df.rename(columns=df.iloc[0])
df.columns=['type','count']
df.insert(0, 'num', list(range(1, 14)))
df
# Out:
#     num  type count
# 4     1    소계   531
# 5     2  종합병원   159
# 6     3    병원    16
# 7     4  요양병원     8
# 8     5  정신병원     2
# 9     6    의원   339
# 10    7  치과병원     -
# 11    8  치과의원     -
# 12    9   보건소     2
# 13   10  보건지소     4
# 14   11    약국     -
# 15   12  한방병원     1
# 16   13   한의원     -

# %%
df.dtypes
# Out:
# num       int64
# type     object
# count    object
# dtype: object

# %%
# 하이픈 0로 변경
df=df.replace(to_replace={'-':'0'})
df
# Out:
#     num  type count
# 4     1    소계   531
# 5     2  종합병원   159
# 6     3    병원    16
# 7     4  요양병원     8
# 8     5  정신병원     2
# 9     6    의원   339
# 10    7  치과병원     0
# 11    8  치과의원     0
# 12    9   보건소     2
# 13   10  보건지소     4
# 14   11    약국     0
# 15   12  한방병원     1
# 16   13   한의원     0

# %%
# count object에서 int 형태로 변환
df['count'] = df['count'].astype('int')
print(df.dtypes)
# Out:
# num       int64
# type     object
# count     int32
# dtype: object

# %%
df.to_csv("C:/Users/user/Final Project/doctor.csv", index = False)
