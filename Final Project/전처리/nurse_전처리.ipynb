# %%
# pip install openpyxl
# Out:
# ...
#      ---------------------------------------- 0.0/250.0 kB ? eta -:--:--
#      ---- -------------------------------- 30.7/250.0 kB 435.7 kB/s eta 0:00:01
#      -------------- ------------------------ 92.2/250.0 kB 1.0 MB/s eta 0:00:01
#      -------------------------------------  245.8/250.0 kB 1.9 MB/s eta 0:00:01
#      -------------------------------------- 250.0/250.0 kB 1.7 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np

# %%
d=pd.read_excel("C:/Users/user/Final Project/원데이터/nurse.xlsx", header =None)

# %%
d
# Out:
#                                   0       1     2     3        4        5   \
# 0   지역별종별_의료인력현황_간호사등(단위_명)_2023년3분기     NaN   NaN   NaN      NaN      NaN
# 1                                NaN     NaN   NaN   NaN      NaN      NaN
# 2                                NaN  인력코드상위   간호사   간호사      간호사      간호사
# 3                                 시도  요양기관종별  간호사계   간호사  가정전문간호사  보건전문간호사
# 4                                 세종       계  1098  1097        -        -
# 5                                 세종    종합병원   787   787        -        -
# 6                                 세종      병원    73    73        -        -
# 7                                 세종    요양병원    38    38        -        -
# 8                                 세종    정신병원     6     6        -        -
# 9                                 세종      의원   120   120        -        -
# 10                                세종    치과병원     -     -        -        -
# ...

# %%
df=d.iloc[4:,1:3]
df=df.rename(columns=df.iloc[0])  
df.columns=['type','n_count']              # 컬럼명 변경 
df.insert(0, 'num', list(range(1, 14)))  # 컬럼 추가 및 숫자 추가
df
# Out:
#     num   type n_count
# 4     1      계    1098
# 5     2   종합병원     787
# 6     3     병원      73
# 7     4   요양병원      38
# 8     5   정신병원       6
# 9     6     의원     120
# 10    7   치과병원       -
# 11    8   치과의원       2
# 12    9    보건소      17
# 13   10   보건지소       3
# 14   11  보건진료소       7
# 15   12   한방병원      36
# 16   13    한의원       9

# %%
df.dtypes
# Out:
# num         int64
# type       object
# n_count    object
# dtype: object

# %%
# 하이픈 0로 변경
df=df.replace(to_replace={'-':'0'})
df
# Out:
#     num   type n_count
# 4     1      계    1098
# 5     2   종합병원     787
# 6     3     병원      73
# 7     4   요양병원      38
# 8     5   정신병원       6
# 9     6     의원     120
# 10    7   치과병원       0
# 11    8   치과의원       2
# 12    9    보건소      17
# 13   10   보건지소       3
# 14   11  보건진료소       7
# 15   12   한방병원      36
# 16   13    한의원       9

# %%
# count object에서 int 형태로 변환
df['n_count'] = df['n_count'].astype('int')
print(df.dtypes)
# Out:
# num         int64
# type       object
# n_count     int32
# dtype: object

# %%
df.to_csv("C:/Users/user/Final Project/csv/nurse.csv", index = False)
