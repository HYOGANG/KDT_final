# %%
import pandas as pd

# %%
hp=pd.read_excel("C:/Users/user/Final Project/원데이터/hospital_mark.xlsx",)

# %%
hp
# Out:
#       NO                병원/약국명 병원/약국구분           전화번호   우편번호  \
# 0      1             세종충남대학교병원    종합병원      1800-3114  30099
# 1      2  의료법인 영제 의료재단 엔케이세종병원    종합병원   044-850-7700  30130
# 2      3              한마음효요양병원    요양병원   044-863-7200  30016
# 3      4              운주산성요양병원    요양병원  044-1544-0240  30009
# 4      5    의료법인 선은의료재단 중앙요양병원    요양병원   044-865-0066  30016
# ..   ...                   ...     ...            ...    ...
# 611  612                  장기약국      약국   044-857-1700  30053
# 612  613                  햇살약국      약국   044-881-9543  30053
# 613  614             세종이마트믿음약국      약국   044-866-4056  30065
# 614  615              메디팜365약국      약국   044-866-6992  30152
# 615  616                세종사랑약국      약국            NaN  30127
#
#                                           소재지주소         위도          경도
# 0              세종특별자치시 보듬7로 20, 세종충남대학교병원 (도담동)  36.519797  127.258243
# 1    세종특별자치시 한누리대로 161, 세종시 NK리움힐 상가 1~8층 (나성동)  36.479636  127.262273
# ...

# %%
hp.columns=['No','name','type','phone','code','address','latitude','longitude']

# %%
hp.fillna(0)
# Out:
#       No                  name  type          phone   code  \
# 0      1             세종충남대학교병원  종합병원      1800-3114  30099
# 1      2  의료법인 영제 의료재단 엔케이세종병원  종합병원   044-850-7700  30130
# 2      3              한마음효요양병원  요양병원   044-863-7200  30016
# 3      4              운주산성요양병원  요양병원  044-1544-0240  30009
# 4      5    의료법인 선은의료재단 중앙요양병원  요양병원   044-865-0066  30016
# ..   ...                   ...   ...            ...    ...
# 611  612                  장기약국    약국   044-857-1700  30053
# 612  613                  햇살약국    약국   044-881-9543  30053
# 613  614             세종이마트믿음약국    약국   044-866-4056  30065
# 614  615              메디팜365약국    약국   044-866-6992  30152
# 615  616                세종사랑약국    약국              0  30127
#
#                                         address   latitude   longitude
# 0              세종특별자치시 보듬7로 20, 세종충남대학교병원 (도담동)  36.519797  127.258243
# 1    세종특별자치시 한누리대로 161, 세종시 NK리움힐 상가 1~8층 (나성동)  36.479636  127.262273
# ...

# %%
hp.dtypes
# Out:
# No             int64
# name          object
# type          object
# phone         object
# code           int64
# address       object
# latitude     float64
# longitude    float64
# dtype: object

# %%
hp.to_csv("C:/Users/user/Final Project/csv/h_mark.csv", index = False)
